# %%
import pyam
# Out:
# C:\Users\flosc\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pyam
#
# File ~\anaconda3\lib\site-packages\pyam\__init__.py:3
#       1 from importlib.metadata import PackageNotFoundError, version
# ----> 3 from pyam.core import (
#       4     IamDataFrame,
#       5     categorize,
#       6     check_aggregate,
#       7     compare,
#       8     concat,
#       9     filter_by_meta,
#      10     read_datapackage,
#      11     require_variable,
#      12     validate,
#      13 )
#      14 from pyam.iiasa import lazy_read_iiasa, read_iiasa
#      15 from pyam.ixmp4 import read_ixmp4
#
# File ~\anaconda3\lib\site-packages\pyam\core.py:9
# ...
